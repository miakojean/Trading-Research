# %%
import pandas as pd

# %%
#read my dataset
data = pd.read_excel("GER40CashBacktest.xlsx")

try:
    print(data.head(10))
except:
    print("Un problème est intervenu lors de la lecture de la base de données ")
# Out:
#                       time      open      high      low    close  tick_volume  \
# 44856  2023-12-29 13:00:00  16745.19  16752.19  16738.9  16739.4         1285
# 44857  2023-12-29 14:00:00  16739.90  16758.40  16738.4  16748.9         1268
# 44858  2023-12-29 15:00:00  16773.70  16781.70  16772.2  16773.7          278
# 44859  2023-12-29 16:00:00  16774.70  16777.20  16758.2  16773.7         1082
# 44860  2023-12-29 17:00:00  16774.20  16789.70  16764.7  16769.7         1343
# 44861  2023-12-29 18:00:00  16769.20  16773.70  16700.7  16735.3         2053
# 44862  2023-12-29 19:00:00  16736.30  16747.30  16720.8  16744.3         1323
# 44863  2023-12-29 20:00:00  16744.50  16764.30  16740.3  16758.3         1167
# 44864  2023-12-29 21:00:00  16757.30  16784.30  16756.8  16782.3          922
# 44865  2023-12-29 22:00:00  16783.00  16785.30  16755.3  16759.9         1599
#
#        spread  real_volume   ha_close    ha_open   ha_high   ha_low  ha_color  \
# ...

# %%
print("Bienvenu au pays mon fils !!! ")
# Out:
# Bienvenu au pays mon fils !!!
